# %%
import numpy as np
import pandas as pd
import matplotlib

# %%
a_df = pd.DataFrame({
    'Country': ['Germany', 'France', 'Belgium', 'Finland'],
    'Population (M)': [82.8, 67.2, 11.4, 5.5],
    'Capital': ['Berlin', 'Paris', 'Brussels', 'Helsinki']
})
a_df
# Out:
#    Country  Population (M)   Capital
# 0  Germany            82.8    Berlin
# 1   France            67.2     Paris
# 2  Belgium            11.4  Brussels
# 3  Finland             5.5  Helsinki

# %%
b_df = pd.DataFrame({
    'Country': ['Germany', 'France', 'Belgium', 'Canada'],
    'HDI': [0.936, 0.901, 0.916, 0.926]
})
b_df
# Out:
#    Country    HDI
# 0  Germany  0.936
# 1   France  0.901
# 2  Belgium  0.916
# 3   Canada  0.926

# %%
c_df=a_df.merge(b_df,on='Country')
c_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916

# %%
left_merged_df=a_df.merge(b_df, on='Country', how='left')
left_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3  Finland             5.5  Helsinki    NaN

# %%
right_merge_df=a_df.merge(b_df, on='Country', how='right')
right_merge_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3   Canada             NaN       NaN  0.926

# %%
outer_merge_df=a_df.merge(b_df, on='Country', how='outer')
outer_merge_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3  Finland             5.5  Helsinki    NaN
# 4   Canada             NaN       NaN  0.926

# %%
outer_merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 4 columns):
# Country           5 non-null object
# Population (M)    4 non-null float64
# Capital           4 non-null object
# HDI               4 non-null float64
# dtypes: float64(2), object(2)
# memory usage: 200.0+ bytes

# %%
aa_df = a_df.set_index("Country")
aa_df
# Out:
#          Population (M)   Capital
# Country
# Germany            82.8    Berlin
# France             67.2     Paris
# Belgium            11.4  Brussels
# Finland             5.5  Helsinki

# %%
bb_df = b_df.set_index("Country")
bb_df
# Out:
#            HDI
# Country
# Germany  0.936
# France   0.901
# Belgium  0.916
# Canada   0.926

# %%
aa_df.join(bb_df, how='left')
# Out:
#          Population (M)   Capital    HDI
# Country
# Germany            82.8    Berlin  0.936
# France             67.2     Paris  0.901
# Belgium            11.4  Brussels  0.916
# Finland             5.5  Helsinki    NaN

# %%
concat_df = pd.concat([a_df, b_df], axis="index", sort=False, ignore_index=True)
concat_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin    NaN
# 1   France            67.2     Paris    NaN
# 2  Belgium            11.4  Brussels    NaN
# 3  Finland             5.5  Helsinki    NaN
# 4  Germany             NaN       NaN  0.936
# 5   France             NaN       NaN  0.901
# 6  Belgium             NaN       NaN  0.916
# 7   Canada             NaN       NaN  0.926

# %%
concat_df.shape
# Out:
# (8, 4)

# %%
concat_df.loc[1]
# Out:
#   Country  Population (M) Capital    HDI
# 1  France            67.2   Paris    NaN
# 1  France             NaN     NaN  0.901

# %% [markdown]
# dictionary.csv
# summer.csv
# winter.csv

# %%
file_dictionary='data/dictionary.csv'
file_summer='data/summer.csv'
file_winter='data/winter.csv'
countries_df=pd.read_csv(file_dictionary)
summer_df=pd.read_csv(file_summer)
winter_df=pd.read_csv(file_winter)
dictionary_df.head()
# Out:
#            Country Code  Population  GDP per Capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN

# %%
summer_df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer_df.rename(columns={'Country':'Code'}, inplace=True)

# %%
summer_df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Code Gender                       Event  \
# 0                  HAJOS, Alfred  HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto  AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios  GRE    Men  100M Freestyle For Sailors
# ...

# %%
winter_df.rename(columns={'Country':'Code'}, inplace=True)

# %%
countries_df.columns
# Out:
# Index(['Country', 'Code', 'Population', 'GDP per Capita'], dtype='object')

# %%
summer_countries_df=summer_df.merge(countries_df, on='Code')
summer_countries_df['season']='summer'
summer_countries_df
# Out:
#        Year    City      Sport Discipline           Athlete Code Gender  \
# 0      1896  Athens   Aquatics   Swimming     HAJOS, Alfred  HUN    Men
# 1      1896  Athens   Aquatics   Swimming     HAJOS, Alfred  HUN    Men
# 2      1896  Athens  Athletics  Athletics  SZOKOLYI, Alajos  HUN    Men
# 3      1896  Athens  Athletics  Athletics      DANI, Nandor  HUN    Men
# 4      1896  Athens  Athletics  Athletics    KELLNER, Gyula  HUN    Men
# ...     ...     ...        ...        ...               ...  ...    ...
# 25737  2012  London  Athletics  Athletics   BARRONDO, Erick  GUA    Men
# 25738  2012  London  Athletics  Athletics     JAMES, Kirani  GRN    Men
# 25739  2012  London  Athletics  Athletics       AMOS, Nijel  BOT    Men
# 25740  2012  London    Sailing    Sailing  KONTIDES, Pavlos  CYP    Men
# 25741  2012  London  Taekwondo  Taekwondo    OBAME, Anthony  GAB    Men
#
#                  Event   Medal    Country  Population  GDP per Capita  season
# ...

# %%
winter_countries_df=winter_df.merge(countries_df, on='Code')
winter_countries_df['season']='winter'
winter_countries_df
# Out:
#       Year       City     Sport Discipline              Athlete Code Gender  \
# 0     1924   Chamonix  Biathlon   Biathlon          BERTHET, G.  FRA    Men
# 1     1924   Chamonix  Biathlon   Biathlon       MANDRILLON, C.  FRA    Men
# 2     1924   Chamonix  Biathlon   Biathlon  MANDRILLON, Maurice  FRA    Men
# 3     1924   Chamonix  Biathlon   Biathlon      VANDELLE, André  FRA    Men
# 4     1924   Chamonix   Curling    Curling          ALDEERT, H.  FRA    Men
# ...    ...        ...       ...        ...                  ...  ...    ...
# 4821  2006      Turin    Skiing  Snowboard      ZIDEK, Radoslav  SVK    Men
# 4822  2010  Vancouver  Biathlon   Biathlon   KUZMINA, Anastazia  SVK  Women
# 4823  2010  Vancouver  Biathlon   Biathlon        HURAJT, Pavol  SVK    Men
# 4824  2010  Vancouver  Biathlon   Biathlon   KUZMINA, Anastazia  SVK  Women
# 4825  2014      Sochi  Biathlon   Biathlon   KUZMINA, Anastazia  SVK  Women
#
# ...

# %%
all_df=pd.concat([summer_countries_df, winter_countries_df], ignore_index=True)
all_df
# Out:
#        Year       City      Sport Discipline             Athlete Code Gender  \
# 0      1896     Athens   Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1      1896     Athens   Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 2      1896     Athens  Athletics  Athletics    SZOKOLYI, Alajos  HUN    Men
# 3      1896     Athens  Athletics  Athletics        DANI, Nandor  HUN    Men
# 4      1896     Athens  Athletics  Athletics      KELLNER, Gyula  HUN    Men
# ...     ...        ...        ...        ...                 ...  ...    ...
# 30563  2006      Turin     Skiing  Snowboard     ZIDEK, Radoslav  SVK    Men
# 30564  2010  Vancouver   Biathlon   Biathlon  KUZMINA, Anastazia  SVK  Women
# 30565  2010  Vancouver   Biathlon   Biathlon       HURAJT, Pavol  SVK    Men
# 30566  2010  Vancouver   Biathlon   Biathlon  KUZMINA, Anastazia  SVK  Women
# 30567  2014      Sochi   Biathlon   Biathlon  KUZMINA, Anastazia  SVK  Women
#
# ...

# %% [markdown]
# pour chaque pays, compter les médailles reçues depuis 1984

# %% [markdown]
# Filtrage

# %%
all_filtre_df=all_df[all_df['Year']>1983]

# %% [markdown]
# comptage des médailles

# %%
all_filtre_et_groupe_df=all_filtre_df.groupby(['Country']).count().sort_values(by='Medal', ascending=False)
all_filtre_et_groupe_df
# Out:
#                        Year  City  Sport  Discipline  Athlete  Code  Gender  \
# Country
# United States          2472  2472   2472        2472     2472  2472    2472
# Germany                1112  1112   1112        1112     1112  1112    1112
# Russia                 1031  1031   1031        1031     1031  1031    1031
# Australia               891   891    891         891      891   891     891
# China                   889   889    889         889      889   889     889
# ...                     ...   ...    ...         ...      ...   ...     ...
# Guatemala                 1     1      1           1        1     1       1
# Grenada                   1     1      1           1        1     1       1
# Eritrea                   1     1      1           1        1     1       1
# Gabon                     1     1      1           1        1     1       1
# Netherlands Antilles*     1     1      1           1        1     1       1
#
# ...

# %% [markdown]
# Identification des 10 premiers pays

# %%
all_filtre_et_groupe_df.head(10)
# Out:
#                Year  City  Sport  Discipline  Athlete  Code  Gender  Event  \
# Country
# United States  2472  2472   2472        2472     2472  2472    2472   2472
# Germany        1112  1112   1112        1112     1112  1112    1112   1112
# Russia         1031  1031   1031        1031     1031  1031    1031   1031
# Australia       891   891    891         891      891   891     891    891
# China           889   889    889         889      889   889     889    889
# Canada          801   801    801         801      801   801     801    801
# Italy           632   632    632         632      632   632     632    632
# Korea, South    587   587    587         587      587   587     587    587
# France          587   587    587         587      587   587     587    587
# Netherlands     563   563    563         563      563   563     563    563
#
#                Medal  Population  GDP per Capita  season
# Country
# United States   2472        2472            2472    2472
# ...

# %%
plot=all_filtre_et_groupe_df.head(10).plot(kind="bar")
plot

# %%
all_filtre_et_groupe_season_df=all_filtre_df.groupby(['Country','season'])['Medal'].count()
all_filtre_et_groupe_season_df
# Out:
# Country          season
# Afghanistan      summer      2
# Algeria          summer     15
# Argentina        summer    173
# Armenia          summer     11
# Australia        summer    876
#                           ...
# Venezuela        summer      7
# Vietnam          summer      2
# Virgin Islands*  summer      1
# Zambia           summer      2
# Zimbabwe         summer      7
# Name: Medal, Length: 157, dtype: int64

# %%
new_df=all_filtre_et_groupe_season_df.unstack(level=-1)
new_df
# Out:
# season           summer  winter
# Country
# Afghanistan         2.0     NaN
# Algeria            15.0     NaN
# Argentina         173.0     NaN
# Armenia            11.0     NaN
# Australia         876.0    15.0
# ...                 ...     ...
# Venezuela           7.0     NaN
# Vietnam             2.0     NaN
# Virgin Islands*     1.0     NaN
# Zambia              2.0     NaN
# Zimbabwe            7.0     NaN
#
# [123 rows x 2 columns]

# %%
new_df_10_summer=new_df.sort_values(by='summer', ascending=False)
new_df_10_summer.head(10)
# Out:
# season          summer  winter
# Country
# United States   2087.0   385.0
# Australia        876.0    15.0
# China            807.0    82.0
# Germany          785.0   327.0
# Russia           768.0   263.0
# United Kingdom   516.0    29.0
# Korea, South     500.0    87.0
# Italy            486.0   146.0
# France           482.0   105.0
# Netherlands      476.0    87.0

# %%
season_count_df = all_df.groupby(["Country", "season"])["Medal"].count().unstack()
season_count_df.fillna(0, inplace=True)
season_count_df["summer"] = season_count_df["summer"].astype(int)
season_count_df["winter"] = season_count_df["winter"].astype(int)
season_count_df.head(10)
# Out:
# season       summer  winter
# Country
# Afghanistan       2       0
# Algeria          15       0
# Argentina       259       0
# Armenia          11       0
# Australia      1189      15
# Austria         146     280
# Azerbaijan       26       0
# Bahamas          27       0
# Bahrain           1       0
# Barbados          1       0

# %%
season_count_df["Total"] = all_filtre_et_groupe_df['Medal']
season_count_df.head(10)
# Out:
# season       summer  winter  Total
# Country
# Afghanistan       2       0    2.0
# Algeria          15       0   15.0
# Argentina       259       0  173.0
# Armenia          11       0   11.0
# Australia      1189      15  891.0
# Austria         146     280  205.0
# Azerbaijan       26       0   26.0
# Bahamas          27       0   23.0
# Bahrain           1       0    1.0
# Barbados          1       0    1.0

# %%
season_count_df.sort_values(by="Total", ascending=False)[["summer", "winter"]].head(10)
# Out:
# season         summer  winter
# Country
# United States    4585     653
# Germany          1305     360
# Russia            768     263
# Australia        1189      15
# China             807      82
# Canada            649     625
# Italy            1296     192
# Korea, South      529      87
# France           1396     152
# Netherlands       851     122

# %%
season_count_df.sort_values(by="Total", ascending=False)[["summer", "winter"]].head(10).plot(kind="bar")
